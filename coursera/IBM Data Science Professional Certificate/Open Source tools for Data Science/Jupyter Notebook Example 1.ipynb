# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Sandeep Aswathnarayana**
# I aspire to be a Deep Learning Researcher in applying my skillset for early, optimal detection of diseases.

# %% [markdown]
# *I am interested in Data Science because it provides me the leverage to understand implicit charecteristics in the data, perform valuable Exploratory Data Analysis (EDA), create meaningful statistical models/charts thereby provide business solutions to my stakeholders using visual storytelling.*

# %% [markdown]
# ### The code in the cell below is an example for addition of two integers:

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# This is an example for
# ***
# Horizontal Rule
# ___
# in Markdown cell
# ***
#
#
#
# - Example
# - of
# - Bulleted lists
#
#
#
# 1. Example
# 2. of
# 3. Numbered lists
#
#
#
# | ID            | Name          | Famously known for  |
# | ------------- |:-------------:| -------------------:|
# | 1             | Einstein      |Theory of Relativity |
# | 2             | Tesla         |AC Electric System   |
#
#
# Plaase refer the [Markdown Chaetsheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Here-Cheatsheet#hr) to create hyperlinks.
#
#
#
# Here's an example of a logo:![alt text](https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png "Logo")
#
#
# No matter what size the line is, there's always room to keep typing more words to form a long sentence for the required example involving **Blocked Quotes**. This is a very long line that will still be quoted properly when it wraps. Oh boy let's keep writing to make sure this is long enough to actually wrap for everyone. Oh, you can *put* **Markdown** into a blockquote.
