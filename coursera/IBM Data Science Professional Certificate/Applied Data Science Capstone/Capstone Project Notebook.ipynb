# %% [markdown]
# # This notebook is an example demonstrating how to get started with GitHub, create a repository and push changes and commits to your repository in order to save your work and keep it up-to-date
# ### For more on how to get started, click [here](https://medium.com/@aklson_DS/how-to-properly-setup-your-github-repository-windows-version-ea596b398b)

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
